# %%
import pandas as pd
import os

# %%
os.listdir('ppvw')
# Out:
# ['ppv.20171229.csv',
#  'ppv.20180102.csv',
#  'ppv.20180103.csv',
#  'ppv.20180110.csv',
#  'ppv.20180109.csv',
#  'ppv.20180104.csv',
#  'ppv.20180112.csv',
#  'ppv.20180111.csv']

# %%
pd.read_csv('ppvw/ppv.20171229.csv')
# Out:
#                                 date  open  high      low       close  \
# AGRX 1969-12-31T19:00:00-05:00   NaN   NaN   NaN    0.000    3.280000
# AMBC 2018-01-12T15:59:47-05:00   NaN   NaN   NaN   16.060   16.070000
# AMPE 2018-01-12T15:52:46-05:00   NaN   NaN   NaN    2.920    2.930000
# APPN 2018-01-12T15:50:00-05:00   NaN   NaN   NaN   36.780   36.759998
# APTO 2018-01-12T15:59:55-05:00   NaN   NaN   NaN    2.470    2.480000
# AREX 2018-01-12T15:59:03-05:00   NaN   NaN   NaN    3.930    3.910000
# ARRY 2018-01-12T15:59:55-05:00   NaN   NaN   NaN   13.700   13.710000
# AXAS 2018-01-12T15:57:35-05:00   NaN   NaN   NaN    2.660    2.660000
# CBIO 2018-01-12T15:31:46-05:00   NaN   NaN   NaN   15.010   15.130000
# CERC 2018-01-12T15:59:43-05:00   NaN   NaN   NaN    2.730    2.740000
# CLMT 2018-01-12T15:59:05-05:00   NaN   NaN   NaN    7.875    7.900000
# CMCM 2018-01-12T15:58:53-05:00   NaN   NaN   NaN   15.730   15.670000
# ...
